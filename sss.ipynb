# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\raj rathod\\Downloads\\archive (2).zip')

# %%
df
# Out:
#                                                  title               genre  \
# 0                                     Notes for My Son               Drama
# 1                                     To Each, Her Own     Romantic comedy
# 2                                        The Lovebirds     Romantic comedy
# 3                                       The Perfection     Horror-thriller
# 4                                    Happy Anniversary     Romantic comedy
# ..                                                 ...                 ...
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...         Documentary
# 579                           Freaks: You're One of Us  Supernatural drama
# 580                                       Squared Love     Romantic comedy
# 581                                         My Own Man         Documentary
# 582                      Biggie: I Got a Story to Tell         Documentary
#
#     language  imdb_score    premiere  runtime  year
# ...

# %%
rr = pd.read_csv('C:\\Users\\raj rathod\\Downloads\\archive (1).zip')

# %%
df.shape
df.head()
df.tail()
# Out:
#                                                  title               genre  \
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...         Documentary
# 579                           Freaks: You're One of Us  Supernatural drama
# 580                                       Squared Love     Romantic comedy
# 581                                         My Own Man         Documentary
# 582                      Biggie: I Got a Story to Tell         Documentary
#
#     language  imdb_score    premiere  runtime  year
# 578  English         7.6   6/12/2019      144  2019
# 579   German         5.4    9/2/2020       92  2020
# 580   Polish         5.0   2/11/2021      102  2021
# 581  English         6.4  12/13/2014       81  2014
# 582  English         6.9    3/1/2021       97  2021

# %%
df.sort_values(by = 'runtime' , ascending=False)
# Out:
#                                                  title                  genre  \
# 186                                       The Irishman            Crime drama
# 472                                        Da 5 Bloods              War drama
# 72                             Springsteen on Broadway           One-man show
# 500                                           Citation                  Drama
# 93                                  The Forest of Love                  Drama
# ..                                                 ...                    ...
# 430                                              Zion             Documentary
# 436  American Factory: A Conversation with the Obamas   Aftershow / Interview
# 95                                             Canvas       Animation / Short
# 362                                   Cops and Robbers      Animation / Short
# 540                                        Sol Levante          Anime / Short
#
# ...

# %%
pd.Series(df['language'].unique()).count()
# Out:
# 38

# %%
pd.Series(df['language'].unique())
# Out:
# 0                        Spanish
# 1                         French
# 2                        English
# 3                     Portuguese
# 4               English/Mandarin
# 5                English/Spanish
# 6                         German
# 7                        Italian
# 8                         Korean
# 9                   Thia/English
# 10                         Hindi
# 11                         Malay
# 12                      Japanese
# 13                       Marathi
# 14                       Swedish
# 15                    Indonesian
# 16                         Dutch
# 17                      Filipino
# 18               Spanish/English
# 19    English/Taiwanese/Mandarin
# 20                      Georgian
# 21                 English/Hindi
# 22               English/Russian
# 23               Spanish/Catalan
# 24      English/Ukranian/Russian
# 25                         Tamil
# 26                     Norwegian
# 27                       Turkish
# ...

# %%
df.groupby(['genre', 'language'])['title'].value_counts()
# Out:
# genre         language    title
# Action        English     6 Underground                   1
#                           Extraction                      1
#                           Point Blank                     1
#                           Polar                           1
#               French      Earth and Blood                 1
#                                                          ..
# War-Comedy    English     War Machine                     1
# Western       English     The Ballad of Buster Scruggs    1
#                           The Ridiculous 6                1
#               Portuguese  The Killer                      1
# Zombie/Heist  English     Army of the Dead                1
# Name: count, Length: 583, dtype: int64

# %%
df[df['title'] == 'Squared Love'].groupby('genre').value_counts()
# Out:
# genre            title         language  imdb_score  premiere   runtime  year
# Romantic comedy  Squared Love  Polish    5.0         2/11/2021  102      2021    1
# Name: count, dtype: int64

# %%
df[df['genre'] == 'Documentary'].groupby('language')['runtime'].mean()
# Out:
# language
# Bengali                      41.000000
# English                      81.741667
# English/Arabic              114.000000
# English/Hindi                32.500000
# English/Japanese             58.000000
# English/Mandarin             59.000000
# English/Russian              90.000000
# English/Spanish              39.200000
# English/Swedish              40.000000
# English/Ukranian/Russian     91.000000
# French                       89.000000
# Georgian                     23.000000
# Japanese                     19.000000
# Korean                       79.000000
# Portuguese                  103.333333
# Spanish                      73.875000
# Spanish/Catalan             116.000000
# Spanish/English              96.000000
# Thai                         85.000000
# Thia/English                 80.000000
# Name: runtime, dtype: float64

# %%
df['genre'].value_counts()
# Out:
# genre
# Documentary                    159
# Drama                           77
# Comedy                          49
# Romantic comedy                 39
# Thriller                        33
#                               ...
# Political thriller               1
# Fantasy                          1
# Romantic comedy-drama            1
# Animation/Musical/Adventure      1
# Supernatural drama               1
# Name: count, Length: 114, dtype: int64

# %%
df['imdb_score'].mean()
# Out:
# 6.275128644939965

# %%
rr
# Out:
#     gender  ssc_percentage ssc_board  hsc_percentage hsc_board hsc_subject  \
# 0        M           67.00    Others           91.00    Others    Commerce
# 1        M           79.33   Central           78.33    Others     Science
# 2        M           65.00   Central           68.00   Central        Arts
# 3        M           56.00   Central           52.00   Central     Science
# 4        M           85.80   Central           73.60   Central    Commerce
# ..     ...             ...       ...             ...       ...         ...
# 210      M           80.60    Others           82.00    Others    Commerce
# 211      M           58.00    Others           60.00    Others     Science
# 212      M           67.00    Others           67.00    Others    Commerce
# 213      F           74.00    Others           66.00    Others    Commerce
# 214      M           62.00   Central           58.00    Others     Science
#
# ...
